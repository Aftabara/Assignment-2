# %%
import pandas  as pd
import numpy as np
import matplotlib as plt
import datetime as dt
import seaborn as sns

# %%
# Display Cab data
dfcab=pd.read_csv('Cab_Data - Copy.csv')

# %%
# Display City Data
dfcity=pd.read_csv('City.csv')

# %%
#Display Transaction data
dftr=pd.read_csv('Transaction_ID.csv')

# %%
#Display Customer data
dfcus=pd.read_csv('Customer_ID.csv')

# %%
dfcab.head()
# Out:
#    Transaction ID Date of Travel   Company        City  KM Travelled  \
# 0      10000011.0     08/01/2016  Pink Cab  ATLANTA GA         30.45
# 1      10000012.0     06/01/2016  Pink Cab  ATLANTA GA         28.62
# 2      10000013.0     02/01/2016  Pink Cab  ATLANTA GA          9.04
# 3      10000014.0     07/01/2016  Pink Cab  ATLANTA GA         33.17
# 4      10000015.0     03/01/2016  Pink Cab  ATLANTA GA          8.73
#
#    Price Charged  Cost of Trip
# 0         370.95       313.635
# 1         358.52       334.854
# 2         125.20        97.632
# 3         377.40       351.602
# 4         114.62        97.776

# %%
dfcus.head()
# Out:
#    Customer ID Gender  Age  Income (USD/Month)
# 0        29290   Male   28               10813
# 1        27703   Male   27                9237
# 2        28712   Male   53               11242
# 3        28020   Male   23               23327
# 4        27182   Male   33                8536

# %%
# Display City
dfcity.head()
# Out:
#              City   Population      Users
# 0     NEW YORK NY   8,405,837    302,149
# 1      CHICAGO IL   1,955,130    164,468
# 2  LOS ANGELES CA   1,595,037    144,132
# 3        MIAMI FL   1,339,155     17,675
# 4  SILICON VALLEY   1,177,609     27,247

# %%
# Transaction
dftr.head()
# Out:
#    Transaction ID  Customer ID Payment_Mode
# 0        10000011        29290         Card
# 1        10000012        27703         Card
# 2        10000013        28712         Cash
# 3        10000014        28020         Cash
# 4        10000015        27182         Card

# %%
#Complete Cab Info
dfcab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359393 entries, 0 to 359392
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Transaction ID  359391 non-null  float64
#  1   Date of Travel  359393 non-null  object
#  2   Company         359392 non-null  object
#  3   City            359392 non-null  object
#  4   KM Travelled    359392 non-null  float64
#  5   Price Charged   359392 non-null  float64
#  6   Cost of Trip    359392 non-null  float64
# dtypes: float64(4), object(3)
# memory usage: 19.2+ MB

# %%
#dropping the row with bad data
indexNames = dfcab[dfcab['Date of Travel'] == '10000026'].index
 
# Delete these row indexes from dataFrame
dfcab.drop(indexNames , inplace=True)

# %%
dfcab['Date of Travel'] = pd.to_datetime(dfcab['Date of Travel'], format='%d/%m/%Y')

# %%
dfcab.shape
# Out:
# (359392, 7)

# %%
dfcity.shape
# Out:
# (20, 3)

# %%
dfcus.shape
# Out:
# (49171, 4)

# %%
dftr.shape
# Out:
# (440098, 3)

# %%
#Dropping the row with missing value
dfcab.dropna()
# Out:
#         Transaction ID Date of Travel     Company           City  \
# 0           10000011.0     2016-01-08    Pink Cab     ATLANTA GA
# 1           10000012.0     2016-01-06    Pink Cab     ATLANTA GA
# 2           10000013.0     2016-01-02    Pink Cab     ATLANTA GA
# 3           10000014.0     2016-01-07    Pink Cab     ATLANTA GA
# 4           10000015.0     2016-01-03    Pink Cab     ATLANTA GA
# ...                ...            ...         ...            ...
# 359388      10440101.0     2018-01-08  Yellow Cab  WASHINGTON DC
# 359389      10440104.0     2018-01-04  Yellow Cab  WASHINGTON DC
# 359390      10440105.0     2018-01-05  Yellow Cab  WASHINGTON DC
# 359391      10440106.0     2018-01-05  Yellow Cab  WASHINGTON DC
# 359392      10440107.0     2018-01-02  Yellow Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip
# 0              30.45         370.95      313.6350
# 1              28.62         358.52      334.8540
# 2               9.04         125.20       97.6320
# 3              33.17         377.40      351.6020
# 4               8.73         114.62       97.7760
# ...              ...            ...           ...
# 359388          4.80          69.24       63.3600
# 359389          8.40         113.75      106.8480
# 359390         27.75         437.07      349.6500
# 359391          8.80         146.19      114.0480
# 359392         12.76         191.58      177.6192
#
# [359391 rows x 7 columns]

# %% [markdown]
# 1 row deleted

# %%
dfcab['Date of Travel'] = pd.to_datetime(dfcab['Date of Travel'], format='%d-%m-%Y')

# %%
dfcab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 359392 entries, 0 to 359392
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Transaction ID  359391 non-null  float64
#  1   Date of Travel  359392 non-null  datetime64[ns]
#  2   Company         359392 non-null  object
#  3   City            359392 non-null  object
#  4   KM Travelled    359392 non-null  float64
#  5   Price Charged   359392 non-null  float64
#  6   Cost of Trip    359392 non-null  float64
# dtypes: datetime64[ns](1), float64(4), object(2)
# memory usage: 21.9+ MB

# %%
dfcab.head()
# Out:
#    Transaction ID Date of Travel   Company        City  KM Travelled  \
# 0      10000011.0     2016-01-08  Pink Cab  ATLANTA GA         30.45
# 1      10000012.0     2016-01-06  Pink Cab  ATLANTA GA         28.62
# 2      10000013.0     2016-01-02  Pink Cab  ATLANTA GA          9.04
# 3      10000014.0     2016-01-07  Pink Cab  ATLANTA GA         33.17
# 4      10000015.0     2016-01-03  Pink Cab  ATLANTA GA          8.73
#
#    Price Charged  Cost of Trip
# 0         370.95       313.635
# 1         358.52       334.854
# 2         125.20        97.632
# 3         377.40       351.602
# 4         114.62        97.776

# %%
#Splitting dates into days, months and year
dfcab['year']= dfcab['Date of Travel'].dt.year
dfcab['month']= dfcab['Date of Travel'].dt.month
dfcab['day']= dfcab['Date of Travel'].dt.day

# %%
dfcab.head()
# Out:
#    Transaction ID Date of Travel   Company        City  KM Travelled  \
# 0      10000011.0     2016-01-08  Pink Cab  ATLANTA GA         30.45
# 1      10000012.0     2016-01-06  Pink Cab  ATLANTA GA         28.62
# 2      10000013.0     2016-01-02  Pink Cab  ATLANTA GA          9.04
# 3      10000014.0     2016-01-07  Pink Cab  ATLANTA GA         33.17
# 4      10000015.0     2016-01-03  Pink Cab  ATLANTA GA          8.73
#
#    Price Charged  Cost of Trip  year  month  day
# 0         370.95       313.635  2016      1    8
# 1         358.52       334.854  2016      1    6
# 2         125.20        97.632  2016      1    2
# 3         377.40       351.602  2016      1    7
# 4         114.62        97.776  2016      1    3

# %%
#Creating Profit column
dfcab['Profit']=dfcab['Price Charged']-dfcab['Cost of Trip']

# %%
dfcab.head()
# Out:
#    Transaction ID Date of Travel   Company        City  KM Travelled  \
# 0      10000011.0     2016-01-08  Pink Cab  ATLANTA GA         30.45
# 1      10000012.0     2016-01-06  Pink Cab  ATLANTA GA         28.62
# 2      10000013.0     2016-01-02  Pink Cab  ATLANTA GA          9.04
# 3      10000014.0     2016-01-07  Pink Cab  ATLANTA GA         33.17
# 4      10000015.0     2016-01-03  Pink Cab  ATLANTA GA          8.73
#
#    Price Charged  Cost of Trip  year  month  day  Profit
# 0         370.95       313.635  2016      1    8  57.315
# 1         358.52       334.854  2016      1    6  23.666
# 2         125.20        97.632  2016      1    2  27.568
# 3         377.40       351.602  2016      1    7  25.798
# 4         114.62        97.776  2016      1    3  16.844

# %%
#Joining cab and transcation dataframe
left = dfcab.set_index(['Transaction ID'])
right = dftr.set_index(['Transaction ID'])

data = left.join(right)

# %%
data.head()
# Out:
#                Date of Travel   Company        City  KM Travelled  \
# Transaction ID
# 10000011.0         2016-01-08  Pink Cab  ATLANTA GA         30.45
# 10000012.0         2016-01-06  Pink Cab  ATLANTA GA         28.62
# 10000013.0         2016-01-02  Pink Cab  ATLANTA GA          9.04
# 10000014.0         2016-01-07  Pink Cab  ATLANTA GA         33.17
# 10000015.0         2016-01-03  Pink Cab  ATLANTA GA          8.73
#
#                 Price Charged  Cost of Trip  year  month  day  Profit  \
# Transaction ID
# 10000011.0             370.95       313.635  2016      1    8  57.315
# 10000012.0             358.52       334.854  2016      1    6  23.666
# 10000013.0             125.20        97.632  2016      1    2  27.568
# 10000014.0             377.40       351.602  2016      1    7  25.798
# 10000015.0             114.62        97.776  2016      1    3  16.844
#
#                 Customer ID Payment_Mode
# Transaction ID
# 10000011.0          29290.0         Card
# 10000012.0          27703.0         Card
# 10000013.0          28712.0         Cash
# 10000014.0          28020.0         Cash
# 10000015.0          27182.0         Card

# %%
data.shape
# Out:
# (359392, 12)

# %%
# Join with customer ID

left = data.set_index([data.index,'Customer ID'])
right = dfcus.set_index(['Customer ID'])
data = left.join(right)

# %%
data.head()
# Out:
#                            Date of Travel   Company        City  KM Travelled  \
# Transaction ID Customer ID
# 10000011.0     29290.0         2016-01-08  Pink Cab  ATLANTA GA         30.45
# 10000012.0     27703.0         2016-01-06  Pink Cab  ATLANTA GA         28.62
# 10000013.0     28712.0         2016-01-02  Pink Cab  ATLANTA GA          9.04
# 10000014.0     28020.0         2016-01-07  Pink Cab  ATLANTA GA         33.17
# 10000015.0     27182.0         2016-01-03  Pink Cab  ATLANTA GA          8.73
#
#                             Price Charged  Cost of Trip  year  month  day  \
# Transaction ID Customer ID
# 10000011.0     29290.0             370.95       313.635  2016      1    8
# 10000012.0     27703.0             358.52       334.854  2016      1    6
# 10000013.0     28712.0             125.20        97.632  2016      1    2
# 10000014.0     28020.0             377.40       351.602  2016      1    7
# 10000015.0     27182.0             114.62        97.776  2016      1    3
#
#                             Profit Payment_Mode Gender  Age  \
# Transaction ID Customer ID
# 10000011.0     29290.0      57.315         Card   Male   28
# 10000012.0     27703.0      23.666         Card   Male   27
# 10000013.0     28712.0      27.568         Cash   Male   53
# 10000014.0     28020.0      25.798         Cash   Male   23
# 10000015.0     27182.0      16.844         Card   Male   33
#
#                             Income (USD/Month)
# Transaction ID Customer ID
# 10000011.0     29290.0                   10813
# 10000012.0     27703.0                    9237
# 10000013.0     28712.0                   11242
# 10000014.0     28020.0                   23327
# 10000015.0     27182.0                    8536

# %%
data.shape
# Out:
# (359392, 14)

# %%
# joining with city

left = data.set_index([data.index,'City'])
right = dfcity.set_index(['City'])
data = left.join(right)

# %%
data.head()
# Out:
#                                       Date of Travel   Company  KM Travelled  \
# Transaction ID Customer ID City
# 10000011.0     29290.0     ATLANTA GA     2016-01-08  Pink Cab         30.45
# 10000012.0     27703.0     ATLANTA GA     2016-01-06  Pink Cab         28.62
# 10000013.0     28712.0     ATLANTA GA     2016-01-02  Pink Cab          9.04
# 10000014.0     28020.0     ATLANTA GA     2016-01-07  Pink Cab         33.17
# 10000015.0     27182.0     ATLANTA GA     2016-01-03  Pink Cab          8.73
#
#                                        Price Charged  Cost of Trip  year  \
# Transaction ID Customer ID City
# 10000011.0     29290.0     ATLANTA GA         370.95       313.635  2016
# 10000012.0     27703.0     ATLANTA GA         358.52       334.854  2016
# 10000013.0     28712.0     ATLANTA GA         125.20        97.632  2016
# 10000014.0     28020.0     ATLANTA GA         377.40       351.602  2016
# 10000015.0     27182.0     ATLANTA GA         114.62        97.776  2016
#
#                                        month  day  Profit Payment_Mode Gender  \
# Transaction ID Customer ID City
# 10000011.0     29290.0     ATLANTA GA      1    8  57.315         Card   Male
# 10000012.0     27703.0     ATLANTA GA      1    6  23.666         Card   Male
# 10000013.0     28712.0     ATLANTA GA      1    2  27.568         Cash   Male
# 10000014.0     28020.0     ATLANTA GA      1    7  25.798         Cash   Male
# 10000015.0     27182.0     ATLANTA GA      1    3  16.844         Card   Male
#
#                                        Age  Income (USD/Month) Population  \
# Transaction ID Customer ID City
# 10000011.0     29290.0     ATLANTA GA   28               10813   814,885
# 10000012.0     27703.0     ATLANTA GA   27                9237   814,885
# 10000013.0     28712.0     ATLANTA GA   53               11242   814,885
# 10000014.0     28020.0     ATLANTA GA   23               23327   814,885
# 10000015.0     27182.0     ATLANTA GA   33                8536   814,885
#
#                                           Users
# Transaction ID Customer ID City
# 10000011.0     29290.0     ATLANTA GA   24,701
# 10000012.0     27703.0     ATLANTA GA   24,701
# 10000013.0     28712.0     ATLANTA GA   24,701
# 10000014.0     28020.0     ATLANTA GA   24,701
# 10000015.0     27182.0     ATLANTA GA   24,701

# %%
data = data.reset_index()

# %%
data = data.reset_index()
# Out:
#     Transaction ID  Customer ID        City Date of Travel   Company  \
# 0       10000011.0      29290.0  ATLANTA GA     2016-01-08  Pink Cab
# 1       10000012.0      27703.0  ATLANTA GA     2016-01-06  Pink Cab
# 2       10000013.0      28712.0  ATLANTA GA     2016-01-02  Pink Cab
# 3       10000014.0      28020.0  ATLANTA GA     2016-01-07  Pink Cab
# 4       10000015.0      27182.0  ATLANTA GA     2016-01-03  Pink Cab
# 5       10000016.0      27318.0  ATLANTA GA     2016-01-07  Pink Cab
# 6       10000017.0      33788.0   AUSTIN TX     2016-01-03  Pink Cab
# 7       10000018.0      34106.0   AUSTIN TX     2016-01-07  Pink Cab
# 8       10000019.0      59799.0   BOSTON MA     2016-01-12  Pink Cab
# 9       10000020.0      57982.0   BOSTON MA     2016-01-06  Pink Cab
# 10      10000021.0      58774.0   BOSTON MA     2016-01-11  Pink Cab
# 11      10000022.0      58627.0   BOSTON MA     2016-01-06  Pink Cab
# 12      10000023.0      59007.0   BOSTON MA     2016-01-11  Pink Cab
# 13      10000024.0      58215.0   BOSTON MA     2016-01-06  Pink Cab
# 14      10000025.0      59372.0   BOSTON MA     2016-01-08  Pink Cab
# 15             NaN          NaN   BOSTON MA     2016-01-10  Pink Cab
# 16      10000027.0      59533.0   BOSTON MA     2016-01-07  Pink Cab
# 17      10000028.0      58346.0   BOSTON MA     2016-01-08  Pink Cab
# 18      10000029.0      58925.0   BOSTON MA     2016-01-02  Pink Cab
# 19      10000030.0      58551.0   BOSTON MA     2016-01-02  Pink Cab
#
#     KM Travelled  Price Charged  Cost of Trip  year  month  day   Profit  \
# 0          30.45         370.95       313.635  2016      1    8   57.315
# 1          28.62         358.52       334.854  2016      1    6   23.666
# 2           9.04         125.20        97.632  2016      1    2   27.568
# 3          33.17         377.40       351.602  2016      1    7   25.798
# 4           8.73         114.62        97.776  2016      1    3   16.844
# 5           6.06          72.43        63.024  2016      1    7    9.406
# 6          44.00         576.15       475.200  2016      1    3  100.950
# 7          35.65         466.10       377.890  2016      1    7   88.210
# 8          14.40         191.61       146.880  2016      1   12   44.730
# 9          10.89         156.98       113.256  2016      1    6   43.724
# 10         39.60         570.83       475.200  2016      1   11   95.630
# 11         21.80         317.27       220.180  2016      1    6   97.090
# 12         12.00         158.01       134.400  2016      1   11   23.610
# 13         32.67         470.94       392.040  2016      1    6   78.900
# 14         25.52         360.79       298.584  2016      1    8   62.206
# 15         15.54         234.78       169.386  2016      1   10   65.394
# 16          6.65         101.39        76.475  2016      1    7   24.915
# 17         34.22         498.02       407.218  2016      1    8   90.802
# 18         21.34         324.21       226.204  2016      1    2   98.006
# 19         41.30         646.06       454.300  2016      1    2  191.760
#
#    Payment_Mode Gender  Age  Income (USD/Month) Population     Users
# 0          Card   Male   28               10813   814,885    24,701
# 1          Card   Male   27                9237   814,885    24,701
# 2          Cash   Male   53               11242   814,885    24,701
# 3          Cash   Male   23               23327   814,885    24,701
# 4          Card   Male   33                8536   814,885    24,701
# 5          Cash   Male   25               13984   814,885    24,701
# 6          Card   Male   23               23788   698,371    14,978
# 7          Card   Male   19               19980   698,371    14,978
# 8          Cash   Male   33               19271   248,968    80,021
# 9          Cash   Male   57                5068   248,968    80,021
# 10         Cash   Male   20               23602   248,968    80,021
# 11         Card   Male   28               27338   248,968    80,021
# 12         Card   Male   63                6683   248,968    80,021
# 13         Cash   Male   25                6862   248,968    80,021
# 14         Cash   Male   53                4912   248,968    80,021
# 15          NaN   Male   28               10813   248,968    80,021
# 16         Card   Male   29               17520   248,968    80,021
# 17         Cash   Male   27               21650   248,968    80,021
# 18         Card   Male   38               26550   248,968    80,021
# 19         Card   Male   25               21734   248,968    80,021

# %%
data.shape
# Out:
# (359392, 18)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359392 entries, 0 to 359391
# Data columns (total 18 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Transaction ID      359391 non-null  float64
#  1   Customer ID         359391 non-null  float64
#  2   City                359392 non-null  object
#  3   Date of Travel      359392 non-null  datetime64[ns]
#  4   Company             359392 non-null  object
#  5   KM Travelled        359392 non-null  float64
#  6   Price Charged       359392 non-null  float64
#  7   Cost of Trip        359392 non-null  float64
#  8   year                359392 non-null  int64
#  9   month               359392 non-null  int64
#  10  day                 359392 non-null  int64
#  11  Profit              359392 non-null  float64
#  12  Payment_Mode        359391 non-null  object
#  13  Gender              359392 non-null  object
#  14  Age                 359392 non-null  int64
#  15  Income (USD/Month)  359392 non-null  int64
#  16  Population          359392 non-null  object
#  17  Users               359392 non-null  object
# dtypes: datetime64[ns](1), float64(6), int64(5), object(6)
# memory usage: 49.4+ MB

# %% [markdown]
# Renaming the column

# %%
for col in data.columns:
    if ' ' in col:
        data = data.rename(columns={col:col.replace(' ','_')})

# %% [markdown]
# #### Changing the data types of some column from float to int

# %%
data.Profit = data.Profit.astype(int)

# %%
data.KM_Travelled  = data.KM_Travelled .astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359392 entries, 0 to 359391
# Data columns (total 18 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Transaction_ID      359391 non-null  float64
#  1   Customer_ID         359391 non-null  float64
#  2   City                359392 non-null  object
#  3   Date_of_Travel      359392 non-null  datetime64[ns]
#  4   Company             359392 non-null  object
#  5   KM_Travelled        359392 non-null  int32
#  6   Price_Charged       359392 non-null  float64
#  7   Cost_of_Trip        359392 non-null  float64
#  8   year                359392 non-null  int64
#  9   month               359392 non-null  int64
#  10  day                 359392 non-null  int64
#  11  Profit              359392 non-null  int32
#  12  Payment_Mode        359391 non-null  object
#  13  Gender              359392 non-null  object
#  14  Age                 359392 non-null  int64
#  15  Income_(USD/Month)  359392 non-null  int64
#  16  Population          359392 non-null  object
#  17  Users               359392 non-null  object
# dtypes: datetime64[ns](1), float64(4), int32(2), int64(5), object(6)
# memory usage: 46.6+ MB

# %% [markdown]
# #### Find out the No. of unique value for each column

# %%
data.nunique()
# Out:
# Transaction_ID        359391
# Customer_ID            46148
# City                      19
# Date_of_Travel          1095
# Company                    2
# KM_Travelled              48
# Price_Charged          99176
# Cost_of_Trip           16291
# year                       3
# month                     12
# day                       31
# Profit                  1319
# Payment_Mode               2
# Gender                     2
# Age                       48
# Income_(USD/Month)     22725
# Population                19
# Users                     19
# dtype: int64

# %%
#tatistical summary of our dataset
data.describe()
# Out:
#        Transaction_ID    Customer_ID   KM_Travelled  Price_Charged  \
# count    3.593910e+05  359391.000000  359392.000000  359392.000000
# mean     1.022076e+07   19191.544271      22.097746     423.443311
# std      1.268054e+05   21012.342233      12.237099     274.378911
# min      1.000001e+07       1.000000       1.000000      15.600000
# 25%      1.011081e+07    2705.000000      12.000000     206.437500
# 50%      1.022104e+07    7459.000000      22.000000     386.360000
# 75%      1.033094e+07   36077.500000      32.000000     583.660000
# max      1.044011e+07   60000.000000      48.000000    2048.030000
#
#         Cost_of_Trip           year          month            day  \
# count  359392.000000  359392.000000  359392.000000  359392.000000
# mean      286.190113    2017.045199       7.500434      15.628447
# std       157.993661       0.800239       3.445095       8.827151
# min        19.000000    2016.000000       1.000000       1.000000
# 25%       151.200000    2016.000000       5.000000       8.000000
# 50%       282.480000    2017.000000       8.000000      16.000000
# 75%       413.683200    2018.000000      10.000000      23.000000
# max       691.200000    2018.000000      12.000000      31.000000
#
#               Profit            Age  Income_(USD/Month)
# count  359392.000000  359392.000000       359392.000000
# mean      136.822495      35.336621        15048.805730
# std       160.243897      12.594184         7969.411952
# min      -220.000000      18.000000         2000.000000
# 25%        28.000000      25.000000         8424.000000
# 50%        81.000000      33.000000        14685.000000
# 75%       190.000000      42.000000        21035.000000
# max      1463.000000      65.000000        35000.000000

# %%
#Yearly profit of both the company
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
pinkprofit=data[data.Company=='Pink Cab'].groupby('year').Profit.mean()
yellowprofit=data[data.Company=='Yellow Cab'].groupby('year').Profit.mean()

# %%
pinkprofit
# Out:
# year
# 2016    67.949761
# 2017    66.715939
# 2018    52.851450
# Name: Profit, dtype: float64

# %%
yellowprofit
# Out:
# year
# 2016    168.895184
# 2017    168.369797
# 2018    142.965497
# Name: Profit, dtype: float64

# %%
#Average yearly profit _ pink cab
ax = pinkprofit.plot.bar(rot=0)

# %%
#Average yearly profit _ yellow cab
ax = yellowprofit.plot.bar(rot=0)

# %%
#Date_maximum no. of travels
datetr=data.groupby('Date_of_Travel').Transaction_ID.count().sort_values(ascending=False)

# %%
datetr.head(10)
# Out:
# Date_of_Travel
# 2018-01-05    2022
# 2017-12-15    1123
# 2017-12-08    1100
# 2018-12-15    1086
# 2017-11-24    1085
# 2018-12-22    1084
# 2018-12-14    1076
# 2017-12-22    1042
# 2018-11-24    1037
# 2018-01-06    1032
# Name: Transaction_ID, dtype: int64

# %%
datetr.tail(10)
# Out:
# Date_of_Travel
# 2016-01-26    94
# 2018-01-22    93
# 2016-01-28    93
# 2018-01-28    92
# 2017-01-25    91
# 2016-01-19    88
# 2016-01-12    86
# 2016-01-11    85
# 2016-01-05    47
# 2016-01-04    25
# Name: Transaction_ID, dtype: int64

# %%
#data grouped bt Transaction ID
mtr=data.groupby(['month']).Transaction_ID.count()
mtr
# Out:
# month
# 1     23173
# 2     18307
# 3     21646
# 4     21434
# 5     23701
# 6     24713
# 7     27676
# 8     31323
# 9     36859
# 10    40852
# 11    42700
# 12    47007
# Name: Transaction_ID, dtype: int64

# %%
ytr=data.groupby(['year']).Transaction_ID.count()
ytr
# Out:
# year
# 2016    107318
# 2017    128510
# 2018    123563
# Name: Transaction_ID, dtype: int64

# %%
#Monthwise Analysis
plt.figure(figsize=(14,6))
sns.barplot(x=mtr.index,y=mtr.values)
plt.title('Travel frequency by Month')
plt.show()

# %%
#Analysis-Yearly Transaction 
plt.figure(figsize=(14,6))
sns.barplot(x=ytr.index,y=ytr.values)
plt.title('Travel frequency by year')
plt.show()

# %%
#Highest number of travel in 2017

# %%
data.head()
# Out:
#    Transaction_ID  Customer_ID        City Date_of_Travel   Company  \
# 0      10000011.0      29290.0  ATLANTA GA     2016-01-08  Pink Cab
# 1      10000012.0      27703.0  ATLANTA GA     2016-01-06  Pink Cab
# 2      10000013.0      28712.0  ATLANTA GA     2016-01-02  Pink Cab
# 3      10000014.0      28020.0  ATLANTA GA     2016-01-07  Pink Cab
# 4      10000015.0      27182.0  ATLANTA GA     2016-01-03  Pink Cab
#
#    KM_Travelled  Price_Charged  Cost_of_Trip  year  month  day  Profit  \
# 0            30         370.95       313.635  2016      1    8      57
# 1            28         358.52       334.854  2016      1    6      23
# 2             9         125.20        97.632  2016      1    2      27
# 3            33         377.40       351.602  2016      1    7      25
# 4             8         114.62        97.776  2016      1    3      16
#
#   Payment_Mode Gender  Age  Income_(USD/Month) Population     Users
# 0         Card   Male   28               10813   814,885    24,701
# 1         Card   Male   27                9237   814,885    24,701
# 2         Cash   Male   53               11242   814,885    24,701
# 3         Cash   Male   23               23327   814,885    24,701
# 4         Card   Male   33                8536   814,885    24,701

# %%
cytr = data.groupby(['year','Company']).Transaction_ID.count().to_frame().reset_index()
cytr
# Out:
#    year     Company  Transaction_ID
# 0  2016    Pink Cab           25079
# 1  2016  Yellow Cab           82239
# 2  2017    Pink Cab           30321
# 3  2017  Yellow Cab           98189
# 4  2018    Pink Cab           29310
# 5  2018  Yellow Cab           94253

# %%
#renaming the column 
data = data.rename(columns={'Income_(USD/Month)':'Income'})

# %%
data.groupby('Company').Income.mean()
# Out:
# Company
# Pink Cab      15058.974136
# Yellow Cab    15045.669817
# Name: Income, dtype: float64

# %%
#Analysis_City 
city = data.groupby('City').Transaction_ID.count()
city
# Out:
# City
# ATLANTA GA         7557
# AUSTIN TX          4896
# BOSTON MA         29691
# CHICAGO IL        56625
# DALLAS TX          7017
# DENVER CO          3825
# LOS ANGELES CA    48033
# MIAMI FL           6454
# NASHVILLE TN       3010
# NEW YORK NY       99885
# ORANGE COUNTY      3982
# PHOENIX AZ         2064
# PITTSBURGH PA      1313
# SACRAMENTO CA      2367
# SAN DIEGO CA      20488
# SEATTLE WA         7997
# SILICON VALLEY     8519
# TUCSON AZ          1931
# WASHINGTON DC     43737
# Name: Transaction_ID, dtype: int64

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
ax = sns.barplot(x="Profit", y="City", data=data,hue='Company')

# %%
import pandas as pd
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler()
column_names_to_normalize = ['Price_Charged', 'Profit', 'Income', 'Cost_of_Trip','KM_Travelled']
x = data[column_names_to_normalize].values
x_scaled = min_max_scaler.fit_transform(x)
df_temp = pd.DataFrame(x_scaled, columns=column_names_to_normalize, index = data.index)
data[column_names_to_normalize] = df_temp

# %%
#Payment Mode Analysis
ax = sns.barplot(x="Payment_Mode", y="Income", data=data,hue='Company')

# %%
#relation between payment and profit
ax = sns.barplot(x="Payment_Mode", y="Profit", data=data,hue='Company')

# %%
#Gender Analysis
pgentr=data[data.Company=='Pink Cab'].groupby(['Gender']).Transaction_ID.count()

# %%
pgentr
# Out:
# Gender
# Female    37480
# Male      47230
# Name: Transaction_ID, dtype: int64

# %%
ygentr=data[data.Company=='Yellow Cab'].groupby(['Gender']).Transaction_ID.count()
ygentr
# Out:
# Gender
# Female    116000
# Male      158681
# Name: Transaction_ID, dtype: int64

# %%
plt.figure(figsize=(8,6))
sns.barplot(x=ygentr.index,y=ygentr.values)
plt.title('Yellow Cab Travel frequency by Gender')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.barplot(x=pgentr.index,y=pgentr.values)
plt.title('Pink Cab Travel frequency by Gender')
plt.show()
